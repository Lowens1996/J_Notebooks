# %% [markdown]
# # Goal 8
#
# This notebook collects data on the languages, frameworks, databases and platforms which people want to work with the most and the most people have worked with already. Hopefully this will give you an idea on whats trending or possible new upcoming languages, frameworks etc, giving you an idea on what to learn or get experince with which might prove to be benificial.

# %%
import numpy as num
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.plotly as plot 
import plotly.graph_objs as graphobj
from plotly import tools 
from plotly.offline import iplot, init_notebook_mode
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Lee/Desktop/4th Year/DataScience/survey_results_public.csv')

# %%
x = data['WantWorkLanguage'].value_counts().nlargest(10)

# %%
x1 = data['HaveWorkedLanguage'].value_counts().nlargest(10)

# %% [markdown]
# ## Languages people want to work with the most
#
# The pie charts and bar charts below display the results on the languages people want to work with the most.

# %% [markdown]
# ### Top 10

# %%
x.plot(kind='pie', figsize=(11,9))

# %% [markdown]
# ### Top 10 Languages already worked with (for comparison to pie chart above)

# %%
x1.plot(kind='pie', figsize=(11,9))

# %%
x.plot(kind='bar', figsize=(9,7))

# %% [markdown]
# ### Top 15

# %%
x2 = data['WantWorkLanguage'].value_counts().nlargest(15)

# %%
x2.plot(kind='pie', figsize=(12,10))

# %%
y = data['WantWorkFramework'].value_counts().nlargest(10)
y1 = data['HaveWorkedFramework'].value_counts().nlargest(10)

# %% [markdown]
# ## Frameworks people want to work with the most
#
# The pie charts and bar charts below display the results on the frameworks people want to work with the most.

# %% [markdown]
# ### Top 10

# %%
y.plot(kind='pie', figsize=(11,9))

# %% [markdown]
# ### Top 10 Frameworks already worked with (for comparison to pie chart above)

# %%
y1.plot(kind='pie', figsize=(11,9))

# %%
y.plot(kind='bar', figsize=(9,7))

# %%
y2 = data['WantWorkFramework'].value_counts().nlargest(15)

# %% [markdown]
# ### Top 15

# %%
y2.plot(kind='pie', figsize=(11,9))

# %%
y2.plot(kind='bar', figsize=(9,7))

# %%
z = data['WantWorkDatabase'].value_counts().nlargest(10)
z1 = data['HaveWorkedDatabase'].value_counts().nlargest(10)

# %% [markdown]
# ## Databases people want to work with the most
#
# The pie charts and bar charts below display the results on the databases people want to work with the most.

# %% [markdown]
# ### Top 10

# %%
z.plot(kind='pie', figsize=(11,9))

# %% [markdown]
# ### Top 10 Databases already worked with (for comparison to pie chart above)

# %%
z1.plot(kind='pie', figsize=(11,9))

# %%
z.plot(kind='bar', figsize=(9,7))

# %%
z2 = data['WantWorkDatabase'].value_counts().nlargest(15)

# %% [markdown]
# ### Top 15

# %%
z2.plot(kind='pie', figsize=(11,9))

# %% [markdown]
# ## Platforms people want to work with the most
#
# The pie charts and bar charts below display the results on the platforms people want to work with the most.

# %%
a = data['WantWorkPlatform'].value_counts().nlargest(10)
a1 = data['HaveWorkedPlatform'].value_counts().nlargest(10)

# %% [markdown]
# ### Top 10

# %%
a.plot(kind='pie', figsize=(11,9))

# %% [markdown]
# ### Top 10 Platforms already worked with (for comparison to pie chart above)

# %%
a1.plot(kind='pie', figsize=(11,9))

# %%
a.plot(kind='bar', figsize=(9,7))

# %% [markdown]
# ### Top 15

# %%
a2 = data['WantWorkPlatform'].value_counts().nlargest(15)
a2.plot(kind='pie', figsize=(11,9))

# %%
a2.plot(kind='bar', figsize=(9,7))
